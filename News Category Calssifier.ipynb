# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (6,6)

from keras import backend as K
from keras.engine.topology import Layer
from keras import initializers, regularizers, constraints

from keras.layers import Dense, Input, LSTM, Bidirectional, Activation, Conv1D, GRU, TimeDistributed
from keras.layers import Dropout, Embedding, GlobalMaxPooling1D, MaxPooling1D, Add, Flatten, SpatialDropout1D
from keras.layers import GlobalAveragePooling1D, BatchNormalization, concatenate
from keras.layers import Reshape, merge, Concatenate, Lambda, Average
from keras.models import Sequential, Model, load_model
from keras.callbacks import ModelCheckpoint
from keras.initializers import Constant
from keras.layers.merge import add

from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.utils import np_utils

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # prepare data

# %%
df = pd.read_json('News_Category_Dataset_v2.json', lines=True)
df.head()
# Out:
#         category                                           headline  \
# 0          CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1  ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2  ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3  ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
#
#            authors                                               link  \
# 0  Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    Andy McDonald  https://www.huffingtonpost.com/entry/will-smit...
# 2       Ron Dicker  https://www.huffingtonpost.com/entry/hugh-gran...
# 3       Ron Dicker  https://www.huffingtonpost.com/entry/jim-carre...
# 4       Ron Dicker  https://www.huffingtonpost.com/entry/julianna-...
#
#                                    short_description       date
# 0  She left her husband. He killed their children... 2018-05-26
# 1                           Of course it has a song. 2018-05-26
# 2  The actor and his longtime girlfriend Anna Ebe... 2018-05-26
# 3  The actor gives Dems an ass-kicking for not fi... 2018-05-26
# 4  The "Dietland" actress said using the bags is ... 2018-05-26

# %%
cates = df.groupby('category')
print("total categories: ", cates.ngroups)
print(cates.size())
# Out:
# total categories:  41
# category
# ARTS               1509
# ARTS & CULTURE     1339
# BLACK VOICES       4528
# BUSINESS           5937
# COLLEGE            1144
# COMEDY             5175
# CRIME              3405
# CULTURE & ARTS     1030
# DIVORCE            3426
# EDUCATION          1004
# ENTERTAINMENT     16058
# ENVIRONMENT        1323
# FIFTY              1401
# FOOD & DRINK       6226
# GOOD NEWS          1398
# GREEN              2622
# HEALTHY LIVING     6694
# HOME & LIVING      4195
# IMPACT             3459
# LATINO VOICES      1129
# MEDIA              2815
# MONEY              1707
# PARENTING          8677
# PARENTS            3955
# POLITICS          32739
# QUEER VOICES       6314
# RELIGION           2556
# SCIENCE            2178
# SPORTS             4884
# STYLE              2254
# STYLE & BEAUTY     9649
# TASTE              2096
# TECH               2082
# THE WORLDPOST      3664
# TRAVEL             9887
# WEDDINGS           3651
# WEIRD NEWS         2670
# WELLNESS          17827
# WOMEN              3490
# WORLD NEWS         2177
# WORLDPOST          2579
# dtype: int64

# %%
# THE WORLDPOST and WORLDPOST should be the same category, so merge them.
df.category = df.category.map(lambda x: "WORDPOST" if x == "THE WORLDPOST" else x)

# %%
# using headlines and short_description as input X
df['text'] = df.headline + " " + df.short_description

# %%
# tokenizing
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.text)
X = tokenizer.texts_to_sequences(df.text)
df['words'] = X

# %%
# delete some empty and short data
df['word_length'] = df.words.apply(lambda i: len(i))
df = df[df.word_length >= 5]

df.head()
# Out:
#         category                                           headline  \
# 0          CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1  ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2  ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3  ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
#
#            authors                                               link  \
# 0  Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    Andy McDonald  https://www.huffingtonpost.com/entry/will-smit...
# 2       Ron Dicker  https://www.huffingtonpost.com/entry/hugh-gran...
# 3       Ron Dicker  https://www.huffingtonpost.com/entry/jim-carre...
# 4       Ron Dicker  https://www.huffingtonpost.com/entry/julianna-...
#
#                                    short_description       date  \
# 0  She left her husband. He killed their children... 2018-05-26
# 1                           Of course it has a song. 2018-05-26
# 2  The actor and his longtime girlfriend Anna Ebe... 2018-05-26
# 3  The actor gives Dems an ass-kicking for not fi... 2018-05-26
# 4  The "Dietland" actress said using the bags is ... 2018-05-26
#
#                                                 text  \
# 0  There Were 2 Mass Shootings In Texas Last Week...
# 1  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2  Hugh Grant Marries For The First Time At Age 5...
# 3  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  Julianna Margulies Uses Donald Trump Poop Bags...
#
#                                                words  word_length
# 0  [74, 101, 257, 1331, 3001, 6, 698, 134, 96, 26...           27
# 1  [42, 1604, 2960, 27762, 5, 25929, 5237, 8, 1, ...           20
# 2  [5877, 5334, 8083, 8, 1, 76, 54, 21, 414, 8469...           25
# 3  [2710, 13374, 3596, 64143, 2295, 13055, 5, 569...           26
# 4  [41003, 36082, 1513, 97, 48, 7915, 3134, 2, 96...           26

# %%
df.word_length.describe()
# Out:
# count    199914.000000
# mean         29.725032
# std          14.024717
# min           5.000000
# 25%          20.000000
# 50%          29.000000
# 75%          36.000000
# max         248.000000
# Name: word_length, dtype: float64

# %%
# using 50 for padding length
maxlen = 50
X = list(sequence.pad_sequences(df.words, maxlen=maxlen))

# %%
# category to id
categories = df.groupby('category').size().index.tolist()
category_int = {}
int_category = {}
for i, k in enumerate(categories):
    category_int.update({k:i})
    int_category.update({i:k})

df['c2id'] = df['category'].apply(lambda x: category_int[x])
# Out:
# C:\Users\inghy\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# # glove embedding

# %%
word_index = tokenizer.word_index

EMBEDDING_DIM = 100

embeddings_index = {}
f = open('glove.6B.100d.txt', 'rt', encoding='UTF8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.array(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s unique tokens.' % len(word_index))
print('Total %s word vectors.' % len(embeddings_index))
# Out:
# Found 116617 unique tokens.
# Total 400000 word vectors.

# %%
embedding_matrix = np.zeros((len(word_index) + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

embedding_layer = Embedding(len(word_index)+1,
                            EMBEDDING_DIM, 
                            embeddings_initializer = Constant(embedding_matrix),
                            input_length = maxlen, 
                            trainable=False)

# %% [markdown]
# # split dataset

# %%
# prepared data

X = np.array(X)
Y = np_utils.to_categorical(list(df.c2id))

#and split to training set and validation set
seed = 29
x_train, x_val, y_train, y_val = train_test_split(X, Y, test_size=0.2, random_state=seed)

# %% [markdown]
# # Bidirectional GRU + Conv

# %%
# Bidrectional LSTM with convolution
# from https://www.kaggle.com/eashish/bidirectional-gru-with-convolution

inp = Input(shape=(maxlen,), dtype='int32')
x = embedding_layer(inp)
x = SpatialDropout1D(0.2)(x)
x = Bidirectional(GRU(128, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(x)
x = Conv1D(64, kernel_size=3)(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
x = concatenate([avg_pool, max_pool])
outp = Dense(len(int_category), activation="softmax")(x)

BiGRU = Model(inp, outp)
BiGRU.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])

BiGRU.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 50)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 50, 100)      11661800    input_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_1 (SpatialDro (None, 50, 100)      0           embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 50, 256)      175872      spatial_dropout1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 48, 64)       49216       bidirectional_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 64)           0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 64)           0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128)          0           global_average_pooling1d_1[0][0]
#                                                                  global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 41)           5289        concatenate_1[0][0]
# ==================================================================================================
# Total params: 11,892,177
# Trainable params: 230,377
# Non-trainable params: 11,661,800
# __________________________________________________________________________________________________

# %%
# training
bigru_history = BiGRU.fit(x_train,
                         y_train,
                         batch_size=128,
                         epochs=20,
                         validation_data=(x_val, y_val))
# Out:
# Train on 159931 samples, validate on 39983 samples
# Epoch 1/20
# 159931/159931 [==============================] - 162s 1ms/step - loss: 1.9031 - acc: 0.4895 - val_loss: 1.5555 - val_acc: 0.5687
# Epoch 2/20
# 159931/159931 [==============================] - 158s 987us/step - loss: 1.5780 - acc: 0.5602 - val_loss: 1.4658 - val_acc: 0.5887
# Epoch 3/20
# 159931/159931 [==============================] - 152s 950us/step - loss: 1.4957 - acc: 0.5785 - val_loss: 1.4323 - val_acc: 0.5943
# Epoch 4/20
headlines
# Out:
# {'status': 'ok',
#  'totalResults': 70,
#  'articles': [{'source': {'id': 'the-washington-post',
#     'name': 'The Washington Post'},
#    'author': 'Antonia Farzan, Katie Shepherd, Jennifer Hassan, Rick Noack',
#    'title': 'Live updates: Fed chair says millions of Americans may never get their jobs back, predicts slow recovery from coronavirus - The Washington Post',
#    'description': 'Congress will likely need to extend additional aid as unemployment remains at historic highs, while the OECD said the global economy is “experiencing the deepest recession since the Great Depression."',
#    'url': 'https://www.washingtonpost.com/nation/2020/06/11/coronavirus-update-us/',
#    'urlToImage': 'https://www.washingtonpost.com/wp-apps/imrs.php?src=https://arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/BV5OHKVJY4I6VJB3X2PWJFFIPU.jpg&w=1440',
#    'publishedAt': '2020-06-11T10:45:17Z',
#    'content': 'MOSCOW Russias coronavirus cases passed the half-million mark Thursday, reaching 502,436, as most isolation measures were lifted, enabling citizens to exercise, shop, go to hair salons and travel in … [+1944 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': None,
#    'title': 'Jobless Claims in the U.S. Set to Rise - The New York Times',
#    'description': 'The latest on stock market and business news during the coronavirus outbreak.',
#    'url': 'https://www.nytimes.com/2020/06/11/business/jobless-claims-stock-market-coronavirus.html',
#    'urlToImage': 'https://www.nytimes.com/newsgraphics/2020/04/09/corona-virus-social-images-by-section/assets/Business_promo.jpg?u=1591871137043',
#    'publishedAt': '2020-06-11T10:25:00Z',
#    'content': 'But Li Keqiang, Chinas premier, had publicly called for the countrys jobless to ignite a stall economy to get the countrys derailed economy back on track. In the process, he laid bare Chinas divergin… [+1139 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Steve Goldstein',
#    'title': "Musk tweets 'lol' at stock market - MarketWatch",
#    'description': '',
#    'url': 'http://www.marketwatch.com/story/musk-tweets-lol-at-stock-market-2020-06-11',
#    'urlToImage': 'https://s.wsj.net/public/resources/MWimages/MW-GP644_MicroS_ZG_20180906154215.jpg',
#    'publishedAt': '2020-06-11T10:17:00Z',
#    'content': "Steven Goldstein is based in London and responsible for MarketWatch's coverage of financial markets in Europe, with a particular focus on global macro and commodities. Previously, he was Washington b… [+121 chars]"},
#   {'source': {'id': None, 'name': "Barron's"},
#    'author': 'Daren Fonda',
#    'title': "Delta Stock Could Be Grounded by Debt - Barron's",
#    'description': '',
#    'url': 'https://www.barrons.com/articles/delta-stock-debt-renegotiations-51591828734',
#    'urlToImage': 'https://images.barrons.com/im-197064/social',
#    'publishedAt': '2020-06-11T10:08:40Z',
#    'content': 'Delta Air Lines\r\n warning that it is seeking to renegotiate debt agreementsand may default if it isnt successfulshould be a wake-up call for equity investors. Airline stocks have rallied lately on ho… [+3689 chars]'},
#   {'source': {'id': None, 'name': "Barron's"},
#    'author': 'Al Root',
#    'title': "Tesla Truck Competitor Nikola Met With Investors. Here’s What It Said. - Barron's",
#    'description': '',
#    'url': 'https://www.barrons.com/articles/tesla-truck-competitor-nikola-met-with-investors-heres-what-it-said-51591824525',
#    'urlToImage': 'https://images.barrons.com/im-196788/social',
#    'publishedAt': '2020-06-11T10:08:36Z',
#    'content': 'Battery and fuel cell heavy duty trucking pioneer\r\n Nikola\r\n presented at an investor conference Wednesday afternoon, for the first time since the highflying startup began life as a publicly traded c… [+2722 chars]'},
#   {'source': {'id': 'fox-news', 'name': 'Fox News'},
#    'author': 'David Aaro',
#    'title': "Johnson & Johnson says coronavirus vaccine's human trials moved up to July - Fox News",
#    'description': 'Johnson & Johnson, the largest health care company in the world, has bumped the start of\xa0human trials for its potential\xa0coronavirus vaccine by two months to begin in July, according to multiple reports.',
#    'url': 'https://www.foxnews.com/health/johnson-johnson-says-coronavirus-vaccines-human-trials-moved-up-to-july',
#    'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2020/06/iStock-1127763296.jpg',
#    'publishedAt': '2020-06-11T09:40:23Z',
#    'content': 'Johnson &amp; Johnson, the largest health care company in the world, has bumped the start of\xa0human trials for its potential\xa0coronavirus vaccine by two months to begin in July, according to multiple r… [+3535 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Elliot Smith',
#    'title': 'Global stocks reel on gloomy Fed outlook and fears of a second coronavirus wave - CNBC',
#    'description': 'Stock markets around the world retreated Thursday as fears over a second wave of coronavirus infections and a gloomy economic outlook from the U.S. Federal Reserve rattled investors.',
#    'url': 'https://www.cnbc.com/2020/06/11/global-stocks-reel-on-gloomy-fed-outlook-and-fears-of-a-second-coronavirus-wave.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106450070-1584542560386gettyimages-1207596525.jpeg?v=1584542605',
#    'publishedAt': '2020-06-11T09:29:10Z',
#    'content': 'Stock markets around the world retreated Thursday as fears over a second wave of coronavirus infections and a gloomy economic outlook from the U.S. Federal Reserve rattled investors.\r\nThe pan-Europea… [+2304 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Naeem Aslam',
#    'title': 'Dow Jones Futures Plunge: Covid-19 Second Wave Fear Mount; Coronavirus Stock Market Rally Fizzle - Forbes',
#    'description': 'The Dow Jones futures plunge due to the fear of second wave of coronavirus in the US as the economy begins. The Fed confirmed that they are going to keep the interest rate lower for extended period and this triggered rally for gold',
#    'url': 'https://www.forbes.com/sites/naeemaslam/2020/06/11/dow-jones-futures-sp-500-stocks-crash/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F44340504%2F0x0.jpg',
#    'publishedAt': '2020-06-11T08:05:32Z',
#    'content': 'The Dow Jones futures are trading lower as investors have genuine qualms about the spike in coronavirus cases in the US. I am skeptical of calling the current spike in coronavirus cases in the US as … [+7769 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Steve Goldstein',
#    'title': 'Stocks in Europe skid as reversal from rally continues - MarketWatch',
#    'description': '',
#    'url': 'https://www.marketwatch.com/story/stocks-in-europe-skid-as-reversal-from-rally-continues-2020-06-11',
#    'urlToImage': 'https://s.marketwatch.com/public/resources/images/MW-II358_paris__ZG_20200611032107.jpg',
#    'publishedAt': '2020-06-11T07:29:31Z',
#    'content': 'European stocks slumped Thursday in early trade, losing ground for a fourth session as traders looked for a new catalyst after the breathtaking rally from the depths of the coronavirus crisis.Decline… [+1803 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Evelyn Cheng',
#    'title': 'U.S. pressure could accelerate growth for markets in Greater China - CNBC',
#    'description': "While U.S. authorities put pressure on Chinese assets, investors remain intent on chasing opportunities in the world's second-largest economy.",
#    'url': 'https://www.cnbc.com/2020/06/11/us-pressure-could-accelerate-growth-for-markets-in-greater-china.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106412032-1582756873616gettyimages-1198368924.jpeg?v=1582756931',
#    'publishedAt': '2020-06-11T04:21:47Z',
#    'content': 'Chinese tourists with facial masks stand in front of the New York Stock Exchange (NYSE) on February 3, 2020 at Wall Street in New York City.\r\nU.S. pressure on Chinese stocks looks set to accelerate t… [+8508 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Neil Vigdor, Elisha Brown',
#    'title': 'Walmart Says It Will No Longer Lock Up African-American Beauty Products - The New York Times',
#    'description': 'The policy had been the subject of a racial discrimination lawsuit that was dropped last year, but the practice had come under renewed scrutiny.',
#    'url': 'https://www.nytimes.com/2020/06/10/business/walmart-black-hair-beauty-products.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/06/10/multimedia/10xp-walmart/10xp-walmart-facebookJumbo.jpg',
#    'publishedAt': '2020-06-11T04:18:47Z',
#    'content': 'The change came as a host of major corporations re-evaluated their business practices and social responsibility after the death of George Floyd and widespread protests over police brutality and discr… [+1153 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Sarah Perez',
#    'title': 'Walmart’s Sam’s Club launches curbside pickup nationwide - TechCrunch',
#    'description': 'Walmart’s online grocery business has been a significant contributor to its growing e-commerce sales, particularly now amid the coronavirus pandemic. Now the retailer is expanding access to curbside pickup at its warehouse club chain, Sam’s Club. Today, Sam’s…',
#    'url': 'http://techcrunch.com/2020/06/10/walmarts-sams-club-launches-curbside-pickup-nationwide/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/02/gettyimages-904500084.jpeg?w=600',
#    'publishedAt': '2020-06-11T04:01:00Z',
#    'content': 'Walmart’s online grocery business has been a significant contributor to its growing e-commerce sales, particularly now amid the coronavirus pandemic. Now the retailer is expanding access to curbside … [+2452 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Clare Duffy, CNN Business',
#    'title': "Days before resigning, CrossFit CEO Greg Glassman told gym owners he doesn't mourn George Floyd - CNN",
#    'description': 'Hours before tweeting controversial statements about George Floyd on Saturday, former CrossFit CEO Greg Glassman made insensitive comments about race on a video call with affiliate gym owners.',
#    'url': 'https://www.cnn.com/2020/06/10/business/greg-glassman-zoom-call/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/200610161358-greg-glassman-crossfit-file-restricted-super-tease.jpg',
#    'publishedAt': '2020-06-11T03:45:48Z',
#    'content': '.@CrossFitCEO: "I, CrossFit HQ, and the CrossFit community will not stand for racism. I made a mistake by the words I chose yesterday.\r\nMy heart is deeply saddened by the pain it has caused. It was a… [+71 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'George Floyd: Amazon bans police use of facial recognition tech - BBC News',
#    'description': 'The move comes after IBM ended its facial recognition activities amid concerns over racial bias.',
#    'url': 'https://www.bbc.com/news/business-52989128',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/10C9C/production/_110246786_facialrecognition3.gif',
#    'publishedAt': '2020-06-11T03:26:04Z',
#    'content': 'Image copyrightGetty Images\r\nTechnology giant Amazon has banned the police from using its controversial facial recognition software for a year.\r\nIt comes after civil rights advocates raised concerns … [+2928 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'Rich Duprey',
#    'title': 'Simon Property Group Drops Acquisition of Taubman Centers - The Motley Fool',
#    'description': 'The mall operator says its peer did little to protect itself during the pandemic.',
#    'url': 'https://www.fool.com/investing/2020/06/10/simon-property-group-drops-acquisition-of-taubman.aspx',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/578212/shopping-mall-retail-mask-getty.jpeg',
#    'publishedAt': '2020-06-11T02:47:01Z',
#    'content': 'Simon Property Group(NYSE:SPG) will no longer pursue its $3.6 billion acquisition of fellow mall operator Taubman Centers(NYSE:TCO). It said the coronavirus pandemic had too great of an impact on Tau… [+1482 chars]'},
#   {'source': {'id': None, 'name': 'CNBC'},
#    'author': 'Reuters',
#    'title': 'White House works to move stalled airline contact tracing plan, sources say - CNBC',
#    'description': 'A debate over how data should be collected from passengers in order to quickly identify and contact people exposed to the coronavirus has dragged on for months without resolution.',
#    'url': 'https://www.cnbc.com/2020/06/11/white-house-works-to-move-stalled-airline-contact-tracing-plan.html',
#    'urlToImage': 'https://image.cnbcfm.com/api/v1/image/106573212-1591841851384gettyimages-1218845714.jpeg?v=1591841750',
#    'publishedAt': '2020-06-11T02:36:00Z',
#    'content': 'The White House wants a plan in place by Sept. 1 for airlines to collect contact tracing information from U.S.-bound international passengers, but will not immediately implement a Centers for Disease… [+1991 chars]'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Cyrus Farivar',
#    'title': 'Uber and Lyft drivers are employees, California regulatory agency finds - NBC News',
#    'description': 'The California Public Utilities Commission officially ruled Tuesday that it would formally consider drivers of Uber and Lyft to be employees.',
#    'url': 'https://www.nbcnews.com/tech/tech-news/uber-lyft-drivers-are-employees-california-regulatory-agency-finds-n1229616',
#    'urlToImage': 'https://media2.s-nbcnews.com/j/newscms/2020_24/3135596/191205-uber-pickup-location-ew-221p_fa2c4d30a398817af27f3a13143d1212.nbcnews-fp-1200-630.jpg',
#    'publishedAt': '2020-06-11T00:54:04Z',
#    'content': 'OAKLAND, Calif. The California Public Utilities Commission, the state government body responsible for licensing and regulating some transportation companies including Uber and Lyft, officially ruled … [+4020 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Ivan Penn',
#    'title': 'PG&E Appoints a New Board as It Eyes Its Bankruptcy Exit - The New York Times',
#    'description': 'The governor of California required the troubled utility to replace its directors as a condition for taking part in a new wildfire liability fund.',
#    'url': 'https://www.nytimes.com/2020/06/10/business/energy-environment/pge-new-board-gavin-newsom.html',
#    'urlToImage': 'https://static01.nyt.com/images/2020/06/10/business/10utility1/10utility1-facebookJumbo.jpg',
#    'publishedAt': '2020-06-11T00:51:48Z',
#    'content': 'If the company does not comply with all of the states requirements, it may not be able to secure the financing it needs for its bankruptcy plan because of investor concerns that it could again become… [+1135 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Billy Bambrough',
#    'title': 'Pentagon Documents Reveal The U.S. Has Planned For A Bitcoin Rebellion - Forbes',
#    'description': 'It\'s been revealed the U.S. Department of Defense has wargamed scenarios involving a Generation Z rebellion that uses bitcoin to undermine and evade "the establishment"...',
#    'url': 'https://www.forbes.com/sites/billybambrough/2020/06/10/pentagon-documents-reveal-the-us-has-planned-for-a-bitcoin-rebellion/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/fit-in/1200x0/filters%3Aformat%28jpg%29/https%3A%2F%2Fspecials-images.forbesimg.com%2Fimageserve%2F5ee15b86298ad300068f3ff2%2F0x0.jpg',
#    'publishedAt': '2020-06-11T00:36:30Z',
#    'content': "Bitcoin has struggled to find support in the U.S. government, with president Donald Trump, along with Treasury secretary Steven Mnuchin, leading the criticism. \r\nNow, it's been revealed the U.S. Depa… [+3276 chars]"},
#   {'source': {'id': None, 'name': 'OilPrice.com'},
#    'author': 'Alex Kimani',
#    'title': 'Bulls Beware A Dark Cloud Is Forming Over Oil Markets - OilPrice.com',
#    'description': "Oil prices have seen an unprecedented rebound in the past two months, but the market isn't in the clear just yet",
#    'url': 'https://oilprice.com/Energy/Energy-General/Bulls-Beware-A-Dark-Cloud-Is-Forming-Over-Oil-Markets.html',
#    'urlToImage': 'https://d32r1sh890xpii.cloudfront.net/article/718x300/2020-06-10_zhzvguowmn.jpg',
#    'publishedAt': '2020-06-11T00:08:11Z',
#    'content': None}]}

# %%
df = pd.DataFrame(top_headlines['articles'])

# %%
df.head(3)
# Out:
#                                               source  \
# 0  {'id': 'the-washington-post', 'name': 'The Was...
# 1             {'id': None, 'name': 'New York Times'}
# 2                {'id': None, 'name': 'MarketWatch'}
#
#                                               author  \
# 0  Antonia Farzan, Katie Shepherd, Jennifer Hassa...
# 1                                               None
# 2                                    Steve Goldstein
#
#                                                title  \
# 0  Live updates: Fed chair says millions of Ameri...
# 1  Jobless Claims in the U.S. Set to Rise - The N...
# 2    Musk tweets 'lol' at stock market - MarketWatch
#
#                                          description  \
# 0  Congress will likely need to extend additional...
# 1  The latest on stock market and business news d...
# 2
#
#                                                  url  \
# 0  https://www.washingtonpost.com/nation/2020/06/...
# 1  https://www.nytimes.com/2020/06/11/business/jo...
# 2  http://www.marketwatch.com/story/musk-tweets-l...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.washingtonpost.com/wp-apps/imrs.ph...  2020-06-11T10:45:17Z
# 1  https://www.nytimes.com/newsgraphics/2020/04/0...  2020-06-11T10:25:00Z
# 2  https://s.wsj.net/public/resources/MWimages/MW...  2020-06-11T10:17:00Z
#
#                                              content
# 0  MOSCOW Russias coronavirus cases passed the ha...
# 1  But Li Keqiang, Chinas premier, had publicly c...
# 2  Steven Goldstein is based in London and respon...

# %%
df['text'] = df.description + " " + df.title
drop_df = df.dropna(axis=0)
df = drop_df
df
# Out:
#                                                source  \
# 0   {'id': 'the-washington-post', 'name': 'The Was...
# 2                 {'id': None, 'name': 'MarketWatch'}
# 3                    {'id': None, 'name': 'Barron's'}
# 4                    {'id': None, 'name': 'Barron's'}
# 5              {'id': 'fox-news', 'name': 'Fox News'}
# 6                        {'id': None, 'name': 'CNBC'}
# 7                      {'id': None, 'name': 'Forbes'}
# 8                 {'id': None, 'name': 'MarketWatch'}
# 9                        {'id': None, 'name': 'CNBC'}
# 10             {'id': None, 'name': 'New York Times'}
# 11         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 12                       {'id': 'cnn', 'name': 'CNN'}
# 13                   {'id': None, 'name': 'BBC News'}
# 14                {'id': None, 'name': 'Motley Fool'}
# 15                       {'id': None, 'name': 'CNBC'}
# 16             {'id': 'nbc-news', 'name': 'NBC News'}
# 17             {'id': None, 'name': 'New York Times'}
# 18                     {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 0   Antonia Farzan, Katie Shepherd, Jennifer Hassa...
# 2                                     Steve Goldstein
# 3                                         Daren Fonda
# 4                                             Al Root
# 5                                          David Aaro
# 6                                        Elliot Smith
# 7                                         Naeem Aslam
# 8                                     Steve Goldstein
# 9                                        Evelyn Cheng
# 10                          Neil Vigdor, Elisha Brown
# 11                                        Sarah Perez
# 12                          Clare Duffy, CNN Business
# 13                   https://www.facebook.com/bbcnews
# 14                                        Rich Duprey
# 15                                            Reuters
# 16                                      Cyrus Farivar
# 17                                          Ivan Penn
# 18                                    Billy Bambrough
#
#                                                 title  \
# 0   Live updates: Fed chair says millions of Ameri...
# 2     Musk tweets 'lol' at stock market - MarketWatch
# 3    Delta Stock Could Be Grounded by Debt - Barron's
# 4   Tesla Truck Competitor Nikola Met With Investo...
# 5   Johnson & Johnson says coronavirus vaccine's h...
# 6   Global stocks reel on gloomy Fed outlook and f...
# 7   Dow Jones Futures Plunge: Covid-19 Second Wave...
# 8   Stocks in Europe skid as reversal from rally c...
# 9   U.S. pressure could accelerate growth for mark...
# 10  Walmart Says It Will No Longer Lock Up African...
# 11  Walmart’s Sam’s Club launches curbside pickup ...
://thumbor.forbes.com/thumbor/fit-in/1200...  2020-06-11T00:36:30Z
#
#                                               content  \
# 0   MOSCOW Russias coronavirus cases passed the ha...
# 2   Steven Goldstein is based in London and respon...
# 3   Delta Air Lines\r\n warning that it is seeking...
# 4   Battery and fuel cell heavy duty trucking pion...
# 5   Johnson &amp; Johnson, the largest health care...
# 6   Stock markets around the world retreated Thurs...
# 7   The Dow Jones futures are trading lower as inv...
# 8   European stocks slumped Thursday in early trad...
# 9   Chinese tourists with facial masks stand in fr...
# 10  The change came as a host of major corporation...
# 11  Walmart’s online grocery business has been a s...
# 12  .@CrossFitCEO: "I, CrossFit HQ, and the CrossF...
# 13  Image copyrightGetty Images\r\nTechnology gian...
# 14  Simon Property Group(NYSE:SPG) will no longer ...
# 15  The White House wants a plan in place by Sept....
# 16  OAKLAND, Calif. The California Public Utilitie...
# 17  If the company does not comply with all of the...
# 18  Bitcoin has struggled to find support in the U...
#
#                                                  text  \
# 0   Congress will likely need to extend additional...
# 2     Musk tweets 'lol' at stock market - MarketWatch
# 3    Delta Stock Could Be Grounded by Debt - Barron's
# 4    Tesla Truck Competitor Nikola Met With Invest...
# 5   Johnson & Johnson, the largest health care com...
# 6   Stock markets around the world retreated Thurs...
# 7   The Dow Jones futures plunge due to the fear o...
# 8    Stocks in Europe skid as reversal from rally ...
# 9   While U.S. authorities put pressure on Chinese...
# 10  The policy had been the subject of a racial di...
# 11  Walmart’s online grocery business has been a s...
# 12  Hours before tweeting controversial statements...
# 13  The move comes after IBM ended its facial reco...
# 14  The mall operator says its peer did little to ...
# 15  A debate over how data should be collected fro...
# 16  The California Public Utilities Commission off...
# 17  The governor of California required the troubl...
# 18  It's been revealed the U.S. Department of Defe...
#
#                                                 words  word_length  \
# 0   [195, 196, 9, 52, 197, 1, 198, 199, 200, 37, 2...           86
# 2   [101, 246, 20, 247, 4, 248, 7, 102, 6, 249, 25...           39
# 3   [107, 262, 263, 264, 22, 11, 20, 265, 2, 266, ...           43
# 4   [278, 7, 279, 280, 281, 282, 283, 284, 285, 28...           45
# 5   [25, 307, 25, 1, 61, 116, 117, 62, 4, 1, 40, 1...           78
# 6   [21, 39, 127, 1, 40, 128, 37, 10, 67, 32, 3, 2...           79
# 7   [1, 71, 72, 73, 74, 319, 134, 10, 23, 112, 320...           98
# 8   [344, 31, 345, 37, 4, 346, 347, 348, 349, 6, 3...           44
# 9   [77, 363, 18, 44, 364, 139, 4, 365, 5, 1, 19, ...           73
# 10  [1, 387, 388, 10, 3, 389, 5, 390, 391, 392, 39...           73
# 11  [83, 148, 149, 80, 14, 35, 3, 150, 151, 2, 12,...           79
# 12  [428, 41, 49, 429, 7, 1, 49, 430, 28, 50, 139,...           84
# 13  [460, 461, 462, 463, 464, 169, 14, 465, 1, 81,...           59
# 14  [172, 173, 174, 78, 481, 28, 145, 146, 482, 12...           62
# 15  [1, 179, 180, 500, 3, 91, 4, 501, 24, 502, 503...           77
# 16  [530, 531, 1, 51, 183, 184, 185, 1, 532, 186, ...           61
# 17  [109, 1, 62, 549, 50, 550, 18, 551, 5, 1, 552,...           78
# 18  [95, 14, 579, 2, 580, 581, 4, 1, 15, 16, 186, ...           74
#
#       sub_category
# 0     QUEER VOICES
# 2           TRAVEL
# 3          DIVORCE
# 4         WELLNESS
# 5         WELLNESS
# 6        PARENTING
# 7         WELLNESS
# 8     QUEER VOICES
# 9         POLITICS
# 10  STYLE & BEAUTY
# 11       PARENTING
# 12       PARENTING
# 13   ENTERTAINMENT
# 14        POLITICS
# 15          TRAVEL
# 16        WELLNESS
# 17        POLITICS
# 18        POLITICS

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df.text)
X = tokenizer.texts_to_sequences(df.text)
df['words'] = X

# %%
df
# Out:
#                                                source  \
# 0   {'id': 'the-washington-post', 'name': 'The Was...
# 2                 {'id': None, 'name': 'MarketWatch'}
# 3                    {'id': None, 'name': 'Barron's'}
# 4                    {'id': None, 'name': 'Barron's'}
# 5              {'id': 'fox-news', 'name': 'Fox News'}
# 6                        {'id': None, 'name': 'CNBC'}
# 7                      {'id': None, 'name': 'Forbes'}
# 8                 {'id': None, 'name': 'MarketWatch'}
# 9                        {'id': None, 'name': 'CNBC'}
# 10             {'id': None, 'name': 'New York Times'}
# 11         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 12                       {'id': 'cnn', 'name': 'CNN'}
# 13                   {'id': None, 'name': 'BBC News'}
# 14                {'id': None, 'name': 'Motley Fool'}
# 15                       {'id': None, 'name': 'CNBC'}
# 16             {'id': 'nbc-news', 'name': 'NBC News'}
# 17             {'id': None, 'name': 'New York Times'}
# 18                     {'id': None, 'name': 'Forbes'}
#
#                                                author  \
# 0   Antonia Farzan, Katie Shepherd, Jennifer Hassa...
# 2                                     Steve Goldstein
# 3                                         Daren Fonda
# 4                                             Al Root
# 5                                          David Aaro
# 6                                        Elliot Smith
# 7                                         Naeem Aslam
# 8                                     Steve Goldstein
# 9                                        Evelyn Cheng
# 10                          Neil Vigdor, Elisha Brown
# 11                                        Sarah Perez
# 12                          Clare Duffy, CNN Business
# 13                   https://www.facebook.com/bbcnews
# 14                                        Rich Duprey
# 15                                            Reuters
# 16                                      Cyrus Farivar
# 17                                          Ivan Penn
# 18                                    Billy Bambrough
#
#                                                 title  \
# 0   Live updates: Fed chair says millions of Ameri...
# 2     Musk tweets 'lol' at stock market - MarketWatch
# 3    Delta Stock Could Be Grounded by Debt - Barron's
# 4   Tesla Truck Competitor Nikola Met With Investo...
# 5   Johnson & Johnson says coronavirus vaccine's h...
# 6   Global stocks reel on gloomy Fed outlook and f...
# 7   Dow Jones Futures Plunge: Covid-19 Second Wave...
# 8   Stocks in Europe skid as reversal from rally c...
# 9   U.S. pressure could accelerate growth for mark...
# 10  Walmart Says It Will No Longer Lock Up African...
# 11  Walmart’s Sam’s Club launches curbside pickup ...
# 12  Days before resigning, CrossFit CEO Greg Glass...
# 13  George Floyd: Amazon bans police use of facial...
# 14  Simon Property Group Drops Acquisition of Taub...
# 15  White House works to move stalled airline cont...
# 16  Uber and Lyft drivers are employees, Californi...
# 17  PG&E Appoints a New Board as It Eyes Its Bankr...
# 18  Pentagon Documents Reveal The U.S. Has Planned...
#
#                                           description  \
# 0   Congress will likely need to extend additional...
# 2
# 3
# 4
# 5   Johnson & Johnson, the largest health care com...
# 6   Stock markets around the world retreated Thurs...
# 7   The Dow Jones fut
://thumbor.forbes.com/thumbor/fit-in/1200...  2020-06-11T00:36:30Z
#
#                                               content  \
# 0   MOSCOW Russias coronavirus cases passed the ha...
# 2   Steven Goldstein is based in London and respon...
# 3   Delta Air Lines\r\n warning that it is seeking...
# 4   Battery and fuel cell heavy duty trucking pion...
# 5   Johnson &amp; Johnson, the largest health care...
# 6   Stock markets around the world retreated Thurs...
# 7   The Dow Jones futures are trading lower as inv...
# 8   European stocks slumped Thursday in early trad...
# 9   Chinese tourists with facial masks stand in fr...
# 10  The change came as a host of major corporation...
# 11  Walmart’s online grocery business has been a s...
# 12  .@CrossFitCEO: "I, CrossFit HQ, and the CrossF...
# 13  Image copyrightGetty Images\r\nTechnology gian...
# 14  Simon Property Group(NYSE:SPG) will no longer ...
# 15  The White House wants a plan in place by Sept....
# 16  OAKLAND, Calif. The California Public Utilitie...
# 17  If the company does not comply with all of the...
# 18  Bitcoin has struggled to find support in the U...
#
#                                                  text  \
# 0   Congress will likely need to extend additional...
# 2     Musk tweets 'lol' at stock market - MarketWatch
# 3    Delta Stock Could Be Grounded by Debt - Barron's
# 4    Tesla Truck Competitor Nikola Met With Invest...
# 5   Johnson & Johnson, the largest health care com...
# 6   Stock markets around the world retreated Thurs...
# 7   The Dow Jones futures plunge due to the fear o...
# 8    Stocks in Europe skid as reversal from rally ...
# 9   While U.S. authorities put pressure on Chinese...
# 10  The policy had been the subject of a racial di...
# 11  Walmart’s online grocery business has been a s...
# 12  Hours before tweeting controversial statements...
# 13  The move comes after IBM ended its facial reco...
# 14  The mall operator says its peer did little to ...
# 15  A debate over how data should be collected fro...
# 16  The California Public Utilities Commission off...
# 17  The governor of California required the troubl...
# 18  It's been revealed the U.S. Department of Defe...
#
#                                                 words  word_length  \
# 0   [98, 38, 99, 100, 2, 101, 102, 103, 10, 104, 1...           86
# 2                     [131, 132, 133, 24, 18, 43, 44]           39
# 3                 [134, 18, 45, 27, 135, 46, 136, 47]           43
# 4   [137, 138, 139, 140, 141, 48, 28, 142, 143, 19...           45
# 5   [20, 20, 1, 49, 144, 145, 146, 6, 1, 50, 12, 1...           78
# 6   [18, 55, 161, 1, 50, 162, 163, 10, 56, 30, 3, ...           79
# 7   [1, 60, 61, 62, 63, 170, 2, 1, 64, 4, 13, 21, ...           98
# 8         [59, 6, 189, 190, 10, 191, 17, 32, 192, 44]           44
# 9   [39, 14, 15, 193, 194, 67, 11, 195, 196, 28, 1...           73
# 10  [1, 206, 68, 33, 1, 207, 4, 3, 69, 208, 209, 2...           73
# 11  [72, 228, 229, 230, 12, 33, 3, 231, 232, 2, 8,...           79
# 12  [247, 80, 248, 249, 250, 81, 35, 36, 11, 251, ...           84
# 13  [1, 88, 267, 268, 269, 270, 8, 89, 90, 271, 75...           59
# 14  [1, 280, 281, 16, 8, 282, 283, 284, 2, 285, 28...           62
# 15  [3, 297, 30, 298, 299, 300, 27, 301, 17, 302, ...           77
# 16  [1, 37, 320, 321, 322, 323, 324, 325, 22, 19, ...           61
# 17  [1, 333, 4, 37, 334, 1, 335, 336, 2, 337, 8, 3...           78
# 18  [351, 33, 352, 1, 14, 15, 353, 4, 354, 12, 355...           74
#
#       sub_category
# 0     QUEER VOICES
# 2           TRAVEL
# 3          DIVORCE
# 4         WELLNESS
# 5         WELLNESS
# 6        PARENTING
# 7         WELLNESS
# 8     QUEER VOICES
# 9         POLITICS
# 10  STYLE & BEAUTY
# 11       PARENTING
# 12       PARENTING
# 13   ENTERTAINMENT
# 14        POLITICS
# 15          TRAVEL
# 16        WELLNESS
# 17        POLITICS
# 18        POLITICS

# %%
df['word_length'] = df.words.apply(lambda i: len(i))
df = df[df.word_length >= 5]
df.head()
# Out:
#                                               source  \
# 0  {'id': 'the-washington-post', 'name': 'The Was...
# 2                {'id': None, 'name': 'MarketWatch'}
# 3                   {'id': None, 'name': 'Barron's'}
# 4                   {'id': None, 'name': 'Barron's'}
# 5             {'id': 'fox-news', 'name': 'Fox News'}
#
#                                               author  \
# 0  Antonia Farzan, Katie Shepherd, Jennifer Hassa...
# 2                                    Steve Goldstein
# 3                                        Daren Fonda
# 4                                            Al Root
# 5                                         David Aaro
#
#                                                title  \
# 0  Live updates: Fed chair says millions of Ameri...
# 2    Musk tweets 'lol' at stock market - MarketWatch
# 3   Delta Stock Could Be Grounded by Debt - Barron's
# 4  Tesla Truck Competitor Nikola Met With Investo...
# 5  Johnson & Johnson says coronavirus vaccine's h...
#
#                                          description  \
# 0  Congress will likely need to extend additional...
# 2
# 3
# 4
# 5  Johnson & Johnson, the largest health care com...
#
#                                                  url  \
# 0  https://www.washingtonpost.com/nation/2020/06/...
# 2  http://www.marketwatch.com/story/musk-tweets-l...
# 3  https://www.barrons.com/articles/delta-stock-d...
# 4  https://www.barrons.com/articles/tesla-truck-c...
# 5  https://www.foxnews.com/health/johnson-johnson...
#
#                                           urlToImage           publishedAt  \
# 0  https://www.washingtonpost.com/wp-apps/imrs.ph...  2020-06-11T10:45:17Z
# 2  https://s.wsj.net/public/resources/MWimages/MW...  2020-06-11T10:17:00Z
# 3        https://images.barrons.com/im-197064/social  2020-06-11T10:08:40Z
# 4        https://images.barrons.com/im-196788/social  2020-06-11T10:08:36Z
# 5  https://static.foxnews.com/foxnews.com/content...  2020-06-11T09:40:23Z
#
#                                              content  \
# 0  MOSCOW Russias coronavirus cases passed the ha...
# 2  Steven Goldstein is based in London and respon...
# 3  Delta Air Lines\r\n warning that it is seeking...
# 4  Battery and fuel cell heavy duty trucking pion...
# 5  Johnson &amp; Johnson, the largest health care...
#
#                                                 text  \
# 0  Congress will likely need to extend additional...
# 2    Musk tweets 'lol' at stock market - MarketWatch
# 3   Delta Stock Could Be Grounded by Debt - Barron's
# 4   Tesla Truck Competitor Nikola Met With Invest...
# 5  Johnson & Johnson, the largest health care com...
#
#                                                words  word_length  \
# 0  [98, 38, 99, 100, 2, 101, 102, 103, 10, 104, 1...           52
# 2                    [131, 132, 133, 24, 18, 43, 44]            7
# 3                [134, 18, 45, 27, 135, 46, 136, 47]            8
# 4  [137, 138, 139, 140, 141, 48, 28, 142, 143, 19...           12
# 5  [20, 20, 1, 49, 144, 145, 146, 6, 1, 50, 12, 1...           44
#
#    sub_category
# 0  QUEER VOICES
# 2        TRAVEL
# 3       DIVORCE
# 4      WELLNESS
# 5      WELLNESS

# %%
df.word_length.describe()
# Out:
# count    18.000000
# mean     33.666667
# std      15.669378
# min       7.000000
# 25%      25.500000
# 50%      39.500000
# 75%      44.000000
# max      59.000000
# Name: word_length, dtype: float64

# %%
X = list(sequence.pad_sequences(df.words, maxlen=maxlen))
X = np.array(X)

# %%
cate = BiGRU.predict(X)

# %%
cate_list = []
for i in range(len(cate)):
    y = cate[i]
    p = np.argmax(y)
    cate_list.append(int_category[p])
    print(int_category[p])
# Out:
# HEALTHY LIVING
# HEALTHY LIVING
# HEALTHY LIVING
# POLITICS
# PARENTING
# FOOD & DRINK
# WEDDINGS
# STYLE
# PARENTING
# QUEER VOICES
# DIVORCE
# COMEDY
# DIVORCE
# HEALTHY LIVING
# BUSINESS
# WELLNESS
# ARTS
# COMEDY

# %%
cate_list
# Out:
# ['HEALTHY LIVING',
#  'HEALTHY LIVING',
#  'HEALTHY LIVING',
#  'POLITICS',
#  'PARENTING',
#  'FOOD & DRINK',
#  'WEDDINGS',
#  'STYLE',
#  'PARENTING',
#  'QUEER VOICES',
#  'DIVORCE',
#  'COMEDY',
#  'DIVORCE',
#  'HEALTHY LIVING',
#  'BUSINESS',
#  'WELLNESS',
#  'ARTS',
#  'COMEDY']

# %%
df['sub_category'] = cate_list

# %%
view = df[['title','description','sub_category']]
view
# Out:
#                                                 title  \
# 0   Live updates: Fed chair says millions of Ameri...
# 2     Musk tweets 'lol' at stock market - MarketWatch
# 3    Delta Stock Could Be Grounded by Debt - Barron's
# 4   Tesla Truck Competitor Nikola Met With Investo...
# 5   Johnson & Johnson says coronavirus vaccine's h...
# 6   Global stocks reel on gloomy Fed outlook and f...
# 7   Dow Jones Futures Plunge: Covid-19 Second Wave...
# 8   Stocks in Europe skid as reversal from rally c...
# 9   U.S. pressure could accelerate growth for mark...
# 10  Walmart Says It Will No Longer Lock Up African...
# 11  Walmart’s Sam’s Club launches curbside pickup ...
# 12  Days before resigning, CrossFit CEO Greg Glass...
# 13  George Floyd: Amazon bans police use of facial...
# 14  Simon Property Group Drops Acquisition of Taub...
# 15  White House works to move stalled airline cont...
# 16  Uber and Lyft drivers are employees, Californi...
# 17  PG&E Appoints a New Board as It Eyes Its Bankr...
# 18  Pentagon Documents Reveal The U.S. Has Planned...
#
#                                           description    sub_category
# 0   Congress will likely need to extend additional...  HEALTHY LIVING
# 2                                                      HEALTHY LIVING
# 3                                                      HEALTHY LIVING
# 4                                                            POLITICS
# 5   Johnson & Johnson, the largest health care com...       PARENTING
# 6   Stock markets around the world retreated Thurs...    FOOD & DRINK
# 7   The Dow Jones futures plunge due to the fear o...        WEDDINGS
# 8                                                               STYLE
# 9   While U.S. authorities put pressure on Chinese...       PARENTING
# 10  The policy had been the subject of a racial di...    QUEER VOICES
# 11  Walmart’s online grocery business has been a s...         DIVORCE
# 12  Hours before tweeting controversial statements...          COMEDY
# 13  The move comes after IBM ended its facial reco...         DIVORCE
# 14  The mall operator says its peer did little to ...  HEALTHY LIVING
# 15  A debate over how data should be collected fro...        BUSINESS
# 16  The California Public Utilities Commission off...        WELLNESS
# 17  The governor of California required the troubl...            ARTS
# 18  It's been revealed the U.S. Department of Defe...          COMEDY

# %%
pip install dill
# Out:
# Collecting dill
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
# Building wheels for collected packages: dill
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78597 sha256=9de58988816a6ba7d2fdb709725e56c36ede30f83dc17fe9ae41459cea535475
#   Stored in directory: c:\users\inghy\appdata\local\pip\cache\wheels\a4\61\fd\c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
# Successfully built dill
# Installing collected packages: dill
# Successfully installed dill-0.3.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import dill as pickle

# %%
filename = 'NewsClf'

# %%
with open(filename, 'wb') as file:
    pickle.dump(BiGRU, file)

# %%
with open(filename, 'rb') as f:
    loaded_model = pickle.load(f)

# %%
loaded_model.predict(X)
# Out:
# array([[3.18178936e-04, 2.59100561e-05, 3.33355332e-04, 3.04321270e-03,
#         5.06694475e-03, 2.19207779e-02, 2.68598297e-03, 4.01008219e-05,
#         1.00252149e-03, 3.84998471e-02, 3.54311639e-03, 4.97574103e-04,
#         3.07378359e-02, 9.56490039e-05, 1.84163020e-03, 8.83957196e-04,
#         2.68137758e-03, 1.09407178e-03, 6.88933628e-03, 3.24617082e-04,
#         9.93738067e-04, 1.18401954e-02, 5.25422037e-01, 2.33715057e-01,
#         8.80574659e-02, 2.95235659e-03, 1.48796666e-04, 4.66531783e-05,
#         3.23745859e-04, 2.40769965e-04, 5.54667087e-04, 6.35273318e-05,
#         1.79493392e-04, 3.45036434e-03, 4.88653139e-04, 2.94133555e-04,
#         5.04247798e-03, 4.35832608e-03, 4.61571726e-05, 7.78409594e-05,
#         1.77513677e-04],
#        [3.08426842e-03, 6.61908276e-03, 6.34519057e-03, 7.41450954e-03,
#         2.73685786e-03, 2.74663456e-02, 3.86550045e-03, 6.47854409e-04,
#         3.26814363e-03, 5.96683798e-03, 3.75550501e-02, 2.64790212e-03,
#         5.76955685e-03, 2.84312665e-02, 2.05123276e-02, 4.14434681e-03,
#         1.22227455e-02, 2.27800701e-02, 2.55520493e-02, 3.86072230e-03,
#         5.42105734e-03, 4.63455450e-03, 4.60015535e-01, 1.69232368e-01,
#         3.76038179e-02, 1.80684142e-02, 8.11193488e-04, 8.97462014e-04,
#         3.02733446e-04, 3.92173650e-03, 8.85164551e-03, 1.34086739e-02,
#         5.90481213e-04, 2.35062977e-03, 5.60249249e-03, 1.19171450e-02,
#         1.10832388e-02, 1.21557480e-02, 9.51368420e-04, 9.45354870e-04,
#         3.43769469e-04],
#        [3.29632871e-03, 3.83889512e-03, 2.14136869e-01, 1.57986535e-03,
#         4.48010303e-03, 1.37096236e-03, 1.66263559e-03, 5.41963317e-02,
#         3.43977241e-03, 5.72653860e-03, 2.55325297e-03, 2.05659354e-03,
#         8.15603603e-03, 1.24704267e-03, 1.43131183e-03, 2.52375932e-04,
#         3.25819268e-03, 7.35638738e-02, 1.07410327e-02, 1.66789547e-03,
